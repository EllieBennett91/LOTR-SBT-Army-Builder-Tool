# %%
import pandas as pd
#build up library of special rules, that can then be imported into the library for Easterling army lists
#also build an army key - input what army you want to play, then it returns the ones which can be allied or enemies

# %%
ElendilHorseData = [['Points', '195'], ['Race', 'Man'], ['Faction', 'Numenor'], ['Troop Type', 'Infantry'], ['Hero?', 'Hero of Legend'], ['Monster?', 'No'], ['Movement', '10'], ['Fight', '7/4+'], ['Strength', '5'], ['Defense', '7'], ['Attack', '3'], ['Wounds', '3'], ['Courage', '6'], ['Might', '3'], ['Will', '3'], ['Fate', '1'], ['Wargear', 'Heavy armour; Narsil; Horse'], ['Heroic Actions', 'Heroic Strike; Heroic Strength; Heroic Defence; Heroic Challenge'], ['Special Rules', 'High King of Gondor and Arnor; Unbending Resolve']] 
Elendil_Horse = pd.DataFrame(ElendilHorseData, columns = ['Profile', 'Elendil on horse'])
Elendil_Horse = Elendil_Horse.set_index('Profile')
Elendil_Horse
# Out:
#                                                  Elendil on horse
# Profile
# Points                                                        195
# Race                                                          Man
# Faction                                                   Numenor
# Troop Type                                               Infantry
# Hero?                                              Hero of Legend
# Monster?                                                       No
# Movement                                                       10
# Fight                                                        7/4+
# Strength                                                        5
# Defense                                                         7
# Attack                                                          3
# Wounds                                                          3
# Courage                                                         6
# ...

# %%
ElendilShieldData = [['Points', '190'], ['Race', 'Man'], ['Faction', 'Numenor'], ['Troop Type', 'Infantry'], ['Hero?', 'Hero of Legend'], ['Monster?', 'No'], ['Movement', '6'], ['Fight', '7/4+'], ['Strength', '5'], ['Defense', '8'], ['Attack', '3'], ['Wounds', '3'], ['Courage', '6'], ['Might', '3'], ['Will', '3'], ['Fate', '1'], ['Wargear', 'Heavy armour; Narsil; Shield'], ['Heroic Actions', 'Heroic Strike; Heroic Strength; Heroic Defence; Heroic Challenge'], ['Special Rules', 'High King of Gondor and Arnor; Unbending Resolve']] 
Elendil_Shield = pd.DataFrame(ElendilShieldData, columns = ['Profile', 'Elendil with Shield'])
Elendil_Shield = Elendil_Shield.set_index('Profile')
Elendil_Shield
# Out:
#                                               Elendil with Shield
# Profile
# Points                                                        190
# Race                                                          Man
# Faction                                                   Numenor
# Troop Type                                               Infantry
# Hero?                                              Hero of Legend
# Monster?                                                       No
# Movement                                                        6
# Fight                                                        7/4+
# Strength                                                        5
# Defense                                                         8
# Attack                                                          3
# Wounds                                                          3
# Courage                                                         6
# ...

# %%
ElendilData = [['Points', '185'], ['Race', 'Man'], ['Faction', 'Numenor'], ['Troop Type', 'Infantry'], ['Hero?', 'Hero of Legend'], ['Monster?', 'No'], ['Movement', '6'], ['Fight', '7/4+'], ['Strength', '5'], ['Defense', '7'], ['Attack', '3'], ['Wounds', '3'], ['Courage', '6'], ['Might', '3'], ['Will', '3'], ['Fate', '1'], ['Wargear', 'Heavy armour; Narsil'], ['Heroic Actions', 'Heroic Strike; Heroic Strength; Heroic Defence; Heroic Challenge'], ['Special Rules', 'High King of Gondor and Arnor; Unbending Resolve']] 
Elendil = pd.DataFrame(ElendilData, columns = ['Profile', 'Elendil'])
Elendil = Elendil.set_index('Profile')
Elendil
# Out:
#                                                           Elendil
# Profile
# Points                                                        185
# Race                                                          Man
# Faction                                                   Numenor
# Troop Type                                               Infantry
# Hero?                                              Hero of Legend
# Monster?                                                       No
# Movement                                                        6
# Fight                                                        7/4+
# Strength                                                        5
# Defense                                                         7
# Attack                                                          3
# Wounds                                                          3
# Courage                                                         6
# ...

# %%
ElendilHorseShieldData = [['Points', '200'], ['Race', 'Man'], ['Faction', 'Numenor'], ['Troop Type', 'Infantry'], ['Hero?', 'Hero of Legend'], ['Monster?', 'No'], ['Movement', '10'], ['Fight', '7/4+'], ['Strength', '5'], ['Defense', '8'], ['Attack', '3'], ['Wounds', '3'], ['Courage', '6'], ['Might', '3'], ['Will', '3'], ['Fate', '1'], ['Wargear', 'Heavy armour; Narsil; Horse; Shield'], ['Heroic Actions', 'Heroic Strike; Heroic Strength; Heroic Defence; Heroic Challenge'], ['Special Rules', 'High King of Gondor and Arnor; Unbending Resolve']] 
Elendil_Horse_Shield = pd.DataFrame(ElendilHorseShieldData, columns = ['Profile', 'Elendil on Horse with Shield'])
Elendil_Horse_Shield = Elendil_Horse_Shield.set_index('Profile')
Elendil_Horse_Shield
# Out:
#                                      Elendil on Horse with Shield
# Profile
# Points                                                        200
# Race                                                          Man
# Faction                                                   Numenor
# Troop Type                                               Infantry
# Hero?                                              Hero of Legend
# Monster?                                                       No
# Movement                                                       10
# Fight                                                        7/4+
# Strength                                                        5
# Defense                                                         8
# Attack                                                          3
# Wounds                                                          3
# Courage                                                         6
# ...

# %%
IsildurData = [['Points', '120'], ['Race', 'Man'], ['Faction', 'Numenor'], ['Troop Type', 'Infantry'], ['Hero?', 'Hero of Valour'], ['Monster?', 'No'], ['Movement', '6'], ['Fight', '6/4+'], ['Strength', '5'], ['Defense', '7'], ['Attack', '3'], ['Wounds', '3'], ['Courage', '6'], ['Might', '3'], ['Will', '2'], ['Fate', '2'], ['Wargear', 'Heavy armour; Hand-and-a-half sword'], ['Heroic Actions', 'Heroic Strike; Heroic Strength'], ['Special Rules', 'Blood of Numenor']] 
Isildur = pd.DataFrame(IsildurData, columns = ['Profile', 'Isildur'])
Isildur = Isildur.set_index('Profile')
Isildur
# Out:
#                                             Isildur
# Profile
# Points                                          120
# Race                                            Man
# Faction                                     Numenor
# Troop Type                                 Infantry
# Hero?                                Hero of Valour
# Monster?                                         No
# Movement                                          6
# Fight                                          6/4+
# Strength                                          5
# Defense                                           7
# Attack                                            3
# Wounds                                            3
# Courage                                           6
# Might                                             3
# Will                                              2
# Fate                                              2
# Wargear         Heavy armour; Hand-and-a-half sword
# ...

# %%
Isildur_Horse_Data = [['Points', '130'], ['Race', 'Man'], ['Faction', 'Numenor'], ['Troop Type', 'Infantry'], ['Hero?', 'Hero of Valour'], ['Monster?', 'No'], ['Movement', '10'], ['Fight', '6/4+'], ['Strength', '5'], ['Defense', '7'], ['Attack', '3'], ['Wounds', '3'], ['Courage', '6'], ['Might', '3'], ['Will', '2'], ['Fate', '2'], ['Wargear', 'Heavy armour; Hand-and-a-half sword; Horse'], ['Heroic Actions', 'Heroic Strike; Heroic Strength'], ['Special Rules', 'Blood of Numenor']] 
Isildur_Horse = pd.DataFrame(Isildur_Horse_Data, columns = ['Profile', 'Isildur on Horse'])
Isildur_Horse = Isildur_Horse.set_index('Profile')
Isildur_Horse
# Out:
#                                           Isildur on Horse
# Profile
# Points                                                 130
# Race                                                   Man
# Faction                                            Numenor
# Troop Type                                        Infantry
# Hero?                                       Hero of Valour
# Monster?                                                No
# Movement                                                10
# Fight                                                 6/4+
# Strength                                                 5
# Defense                                                  7
# Attack                                                   3
# Wounds                                                   3
# Courage                                                  6
# Might                                                    3
# Will                                                     2
# ...

# %%
Isildur_Shield_Data = [['Points', '125'], ['Race', 'Man'], ['Faction', 'Numenor'], ['Troop Type', 'Infantry'], ['Hero?', 'Hero of Valour'], ['Monster?', 'No'], ['Movement', '6'], ['Fight', '6/4+'], ['Strength', '5'], ['Defense', '8'], ['Attack', '3'], ['Wounds', '3'], ['Courage', '6'], ['Might', '3'], ['Will', '2'], ['Fate', '2'], ['Wargear', 'Heavy armour; Hand-and-a-half sword; Shield'], ['Heroic Actions', 'Heroic Strike; Heroic Strength'], ['Special Rules', 'Blood of Numenor']] 
Isildur_Shield = pd.DataFrame(Isildur_Shield_Data, columns = ['Profile', 'Isildur with Shield'])
Isildur_Shield = Isildur_Shield.set_index('Profile')
Isildur_Shield
# Out:
#                                         Isildur with Shield
# Profile
# Points                                                  125
# Race                                                    Man
# Faction                                             Numenor
# Troop Type                                         Infantry
# Hero?                                        Hero of Valour
# Monster?                                                 No
# Movement                                                  6
# Fight                                                  6/4+
# Strength                                                  5
# Defense                                                   8
# Attack                                                    3
# Wounds                                                    3
# Courage                                                   6
# Might                                                     3
# ...

# %%
Isildur_Ring_Data = [['Points', '120'], ['Race', 'Man'], ['Faction', 'Numenor'], ['Troop Type', 'Infantry'], ['Hero?', 'Hero of Valour'], ['Monster?', 'No'], ['Movement', '6'], ['Fight', '6/4+'], ['Strength', '5'], ['Defense', '7'], ['Attack', '3'], ['Wounds', '3'], ['Courage', '6'], ['Might', '3'], ['Will', '2'], ['Fate', '2'], ['Wargear', 'Heavy armour; Hand-and-a-half sword; The Ring'], ['Heroic Actions', 'Heroic Strike; Heroic Strength'], ['Special Rules', 'Blood of Numenor']] 
Isildur_Ring = pd.DataFrame(Isildur_Ring_Data, columns = ['Profile', 'Isildur with The Ring'])
Isildur_Ring = Isildur_Ring.set_index('Profile')
Isildur_Ring
# Out:
#                                         Isildur with The Ring
# Profile
# Points                                                    120
# Race                                                      Man
# Faction                                               Numenor
# Troop Type                                           Infantry
# Hero?                                          Hero of Valour
# Monster?                                                   No
# Movement                                                    6
# Fight                                                    6/4+
# Strength                                                    5
# Defense                                                     7
# Attack                                                      3
# Wounds                                                      3
# Courage                                                     6
# Might                                                       3
# ...

# %%
#Isildur with horse and shield
Isildur_Horse_Shield_Data = [['Points', '135'], ['Race', 'Man'], ['Faction', 'Numenor'], ['Troop Type', 'Infantry'], ['Hero?', 'Hero of Valour'], ['Monster?', 'No'], ['Movement', '10'], ['Fight', '6/4+'], ['Strength', '5'], ['Defense', '8'], ['Attack', '3'], ['Wounds', '3'], ['Courage', '6'], ['Might', '3'], ['Will', '2'], ['Fate', '2'], ['Wargear', 'Heavy armour; Hand-and-a-half sword; Horse; Shield'], ['Heroic Actions', 'Heroic Strike; Heroic Strength'], ['Special Rules', 'Blood of Numenor']] 
Isildur_Horse_Shield = pd.DataFrame(Isildur_Horse_Shield_Data, columns = ['Profile', 'Isildur on Horse with Shield'])
Isildur_Horse_Shield = Isildur_Horse_Shield.set_index('Profile')
Isildur_Horse_Shield
# Out:
#                                      Isildur on Horse with Shield
# Profile
# Points                                                        135
# Race                                                          Man
# Faction                                                   Numenor
# Troop Type                                               Infantry
# Hero?                                              Hero of Valour
# Monster?                                                       No
# Movement                                                       10
# Fight                                                        6/4+
# Strength                                                        5
# Defense                                                         8
# Attack                                                          3
# Wounds                                                          3
# Courage                                                         6
# ...

# %%
#Isildur with horse and the ring
Isildur_Horse_Ring_Data = [['Points', '130'], ['Race', 'Man'], ['Faction', 'Numenor'], ['Troop Type', 'Infantry'], ['Hero?', 'Hero of Valour'], ['Monster?', 'No'], ['Movement', '10'], ['Fight', '6/4+'], ['Strength', '5'], ['Defense', '7'], ['Attack', '3'], ['Wounds', '3'], ['Courage', '6'], ['Might', '3'], ['Will', '2'], ['Fate', '2'], ['Wargear', 'Heavy armour; Hand-and-a-half sword; Horse; The Ring'], ['Heroic Actions', 'Heroic Strike; Heroic Strength'], ['Special Rules', 'Blood of Numenor']] 
Isildur_Horse_Ring = pd.DataFrame(Isildur_Horse_Ring_Data, columns = ['Profile', 'Isildur on Horse with The Ring'])
Isildur_Horse_Ring = Isildur_Horse_Ring.set_index('Profile')
Isildur_Horse_Ring
# Out:
#                                    Isildur on Horse with The Ring
# Profile
# Points                                                        130
# Race                                                          Man
# Faction                                                   Numenor
# Troop Type                                               Infantry
# Hero?                                              Hero of Valour
# Monster?                                                       No
# Movement                                                       10
# Fight                                                        6/4+
# Strength                                                        5
# Defense                                                         7
# Attack                                                          3
# Wounds                                                          3
# Courage                                                         6
# ...

# %%
#Isildur with shield and the ring
Isildur_Shield_Ring_Data = [['Points', '125'], ['Race', 'Man'], ['Faction', 'Numenor'], ['Troop Type', 'Infantry'], ['Hero?', 'Hero of Valour'], ['Monster?', 'No'], ['Movement', '6'], ['Fight', '6/4+'], ['Strength', '5'], ['Defense', '8'], ['Attack', '3'], ['Wounds', '3'], ['Courage', '6'], ['Might', '3'], ['Will', '2'], ['Fate', '2'], ['Wargear', 'Heavy armour; Hand-and-a-half sword; Shield; The Ring'], ['Heroic Actions', 'Heroic Strike; Heroic Strength'], ['Special Rules', 'Blood of Numenor']] 
Isildur_Shield_Ring = pd.DataFrame(Isildur_Shield_Ring_Data, columns = ['Profile', 'Isildur with Shield and The Ring'])
Isildur_Shield_Ring = Isildur_Shield_Ring.set_index('Profile')
Isildur_Shield_Ring
# Out:
#                                  Isildur with Shield and The Ring
# Profile
# Points                                                        125
# Race                                                          Man
# Faction                                                   Numenor
# Troop Type                                               Infantry
# Hero?                                              Hero of Valour
# Monster?                                                       No
# Movement                                                        6
# Fight                                                        6/4+
# Strength                                                        5
# Defense                                                         8
# Attack                                                          3
# Wounds                                                          3
# Courage                                                         6
# ...

# %%
#Isildure with shield and ring and horse
Isildur_Shield_Ring_Horse_Data = [['Points', '135'], ['Race', 'Man'], 
                            ['Faction', 'Numenor'], ['Troop Type', 'Infantry'], 
                            ['Hero?', 'Hero of Valour'], ['Monster?', 'No'], 
                            ['Movement', '10'], ['Fight', '6/4+'], 
                            ['Strength', '5'], ['Defense', '8'], 
                            ['Attack', '3'], ['Wounds', '3'], ['Courage', '6'], 
                            ['Might', '3'], ['Will', '2'], ['Fate', '2'], 
                            ['Wargear', 'Heavy armour; Hand-and-a-half sword; Shield; Horse; The Ring'], 
                            ['Heroic Actions', 'Heroic Strike; Heroic Strength'], 
                            ['Special Rules', 'Blood of Numenor']] 
Isildur_Shield_Ring_Horse = pd.DataFrame(Isildur_Shield_Ring_Horse_Data, columns = ['Profile', 'Isildur on Horse with Shield and The Ring'])
Isildur_Shield_Ring_Horse = Isildur_Shield_Ring_Horse.set_index('Profile')
Isildur_Shield_Ring_Horse
# Out:
#                         Isildur on Horse with Shield and The Ring
# Profile
# Points                                                        135
# Race                                                          Man
# Faction                                                   Numenor
# Troop Type                                               Infantry
# Hero?                                              Hero of Valour
# Monster?                                                       No
# Movement                                                       10
# Fight                                                        6/4+
# Strength                                                        5
# Defense                                                         8
# Attack                                                          3
# Wounds                                                          3
# Courage                                                         6
# ...

# %%
#Captain of Numenor - not complete profile
Captain_Numenor_Data = [['Points', '50'], ['Race', 'Man'], 
                            ['Faction', 'Numenor'], ['Troop Type', 'Infantry'], 
                            ['Hero?', 'Hero of Fortitude'], ['Monster?', 'No'], 
                            ['Movement', '6'], ['Fight', '5/4+'], 
                            ['Strength', '5'], ['Defense', '5'], 
                            ['Attack', '2'], ['Wounds', '2'], ['Courage', '4'], 
                            ['Might', '2'], ['Will', '1'], ['Fate', '1'], 
                            ['Wargear', 'Armour; Sword'],
                            ['Heroic Actions', 'Heroic Strike; Heroic Strength'], 
                            ['Special Rules', 'Blood of Numenor']] 
Captain_Numenor = pd.DataFrame(Captain_Numenor_Data, columns = ['Profile', 'Captain of Numenor'])
Captain_Numenor = Captain_Numenor.set_index('Profile')
Captain_Numenor
# Out:
#                             Captain of Numenor
# Profile
# Points                                      50
# Race                                       Man
# Faction                                Numenor
# Troop Type                            Infantry
# Hero?                        Hero of Fortitude
# Monster?                                    No
# Movement                                     6
# Fight                                     5/4+
# Strength                                     5
# Defense                                      5
# Attack                                       2
# Wounds                                       2
# Courage                                      4
# Might                                        2
# Will                                         1
# Fate                                         1
# Wargear                          Armour; Sword
# Heroic Actions  Heroic Strike; Heroic Strength
# Special Rules                 Blood of Numenor

# %%
#input function for the wargear - separate with commas (like in Niek's code)
print('Additional Wargear. Please type each item with a capital letter at the start, and separate each item with a comma, e.g. Horse, Sword.')
x = input()
# Out:
# Additional Wargear. Please type each item with a capital letter at the start, and separate each item with a comma, e.g. Horse, Sword.
# Horse, Sword, Lance

# %%
#create code that for each item of wargear, it changes the profile.
#NOTE: the code needs to take into account whether the profile is a hero or not (changes points value)

# %%
#Captain of Numenor with Horse

# %%
#Captain of Numenor with Horse and Bow

# %%
#Captain of Numenor with Horse and Heavy Armour

# %%
#Captain of Numenor with Horse and Lance

# %%
#Captain of Numenor with Horse and Shield

# %%
#Captain of Numenor with Bow

# %%
#Captain of Numenor with Bow and Heavy Armour

# %%
#Captain of Numenor with Heavy Armour

# %%
#Captain of Numenor with Heavy Armour and Shield

# %%
#Captain of Numenor with Shield

# %%
#Captain of Numenor with Horse and Bow and Heavy Armour

# %%
#Captain of Numenor with Horse and Bow and Lance

# %%
#Captain of Numenor with Horse and Heavy Armour and Lance

# %%
#Captain of Numenor with Horse and Heavy Armour and Shield

# %%
#Captain of Numenor with Horse and Lance and Shield

# %%
#Captain of Numenor with Horse and Bow and Heavy Armour and Lance

# %%
#Captain of Numenor with Horse and Shield and Heavy Armour and Lance
